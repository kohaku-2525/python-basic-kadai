# %%
def show_user_name():
  user_name = "侍太郎"

  print(user_name)

show_user_name()
# Out:
# 侍太郎

# %%
def show_user_name():
  user_name = "侍太郎"
  print(user_name)

show_user_name()

# The variable 'user_name' is defined within the function's scope and cannot be accessed outside.
# If you intend to print a global variable, it needs to be defined globally.
# print(user_name)
# Out:
# 侍太郎

# %%
user_name = "侍花子"

def show_user_name():

  user_name = "侍太郎"
  print(user_name)

show_user_name()

print(user_name)
# Out:
# 侍花子
# 侍花子

# %%
price1 = 100
price2 = 200

tax = 1.1

def total():
  return price1 + price2

print(total() * tax)
# Out:
# 330.0

# %%
class Product:
  def __init__(self):
    self.name = ""

shampoo = Product()
shampoo.name = "シャンプー"

print(shampoo.name)
# Out:
# シャンプー

# %%
class Product:
  def __init__(self):
    self.name = ""

  def set_name(self, name):
    self.name = name

  def show_name(self):
    print(self.name)

coffee = Product()

coffee.set_name("コーヒー")
coffee.show_name()
# Out:
# コーヒー

# %%
class User:

  def __init__(self, name, age, gender):
    self.name = name
    self.age = age
    self.gender = gender

user = User("侍太郎", 36, "男性")

print(user.name)
print(user.age)
print(user.gender)
# Out:
# 侍太郎
# 36
# 男性

# %%
import datetime

class event:
  def __init__(self, name, date, location):
    self.name = name
    self.date = date # datetime.dateオブジェクトを想定
    self.location = location

  def days_until_event(self):
    today = datetime.date.today()
    delta = self.date - today
    return delta.days

# 1. 以下のインスタンスを作成してください
#   - イベント名：プログラム初心者向けセミナー
#   - 開催日：現在よりも未来の日付
#   - 開催場所：東京国際フォーラム

# 現在の日付から30日後の日付を未来の日付として設定
future_date = datetime.date.today() + datetime.timedelta(days=30)
event_instance = event("プログラム初心者向けセミナー", future_date, "東京国際フォーラム")

# 2. 各属性にアクセスし、値を出力
print(f"イベント名: {event_instance.name}")
print(f"開催日: {event_instance.date}")
print(f"開催場所: {event_instance.location}")

# 3. イベント開催日までの日数を返すメソッドを実行し、その結果を出力する
print(f"イベント開催日までの日数: {event_instance.days_until_event()}日")
# Out:
# イベント名: プログラム初心者向けセミナー
# 開催日: 2025-12-21
# 開催場所: 東京国際フォーラム
# イベント開催日までの日数: 30日

# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def printinfo(self):
    print(f"名前: {self.name}")
    print(f"年齢: {self.age}")

human_instance = Human("侍太郎", 28)

human_instance.printinfo()
# Out:
# 名前: 侍太郎
# 年齢: 28
