# %%
def say_good_morning():
  print("おはようございます！")
  print("昨日はよく寝れましたか？")
  print("今日も頑張りましょう！")

def say_good_evening():
  print("こんばんは！")
  print("今日も一日お疲れさまでした。")

say_good_morning()

say_good_evening()
# Out:
# おはようございます！
# 昨日はよく寝れましたか？
# 今日も頑張りましょう！
# こんばんは！
# 今日も一日お疲れさまでした。

# %%
def calculate_total(price):
  total = price + 500

  print(f"{total}円")

calculate_total(1200)
# Out:
# 1700円

# %%
def add_two_arguments(price, shipping_fee):
  total = price + shipping_fee

  print(f"{total}円")

add_two_arguments(1200, 500)
# Out:
# 1700円

# %%
purchased = True

def is_purchased():
  if(purchased):
    return True
  else:
    return False

if (is_purchased()):
  print("商品は購入済みです。")
# Out:
# 商品は購入済みです。

# %%
# greet_user 関数の定義
def greet_user(user_name: str) -> str:
  if not user_name:
    return "こんにちは、ゲストさん！"
  else:
    return f"こんにちは、{user_name}さん！"

# 引数として '侍 太郎' を渡した場合の実行結果
print(greet_user('侍 太郎'))

# 引数として空文字を渡した場合の実行結果
print(greet_user(''))
# Out:
# こんにちは、侍 太郎さん！
# こんにちは、ゲストさん！

# %%
def add_two_arguments(price,shipping_fee):
  total = price + shipping_fee
  print(f"{total}円")

add_two_arguments(110,10)
# Out:
# 120円

# %%
def calculate_price_with_tax(price, tax_rate):
  tax_amount = price * (tax_rate / 100)
  total = price + tax_amount
  return total

item_price = 110
consumption_tax_rate = 10
result = calculate_price_with_tax(item_price, consumption_tax_rate)
print(f"合計金額は{result}円です。")
# Out:
# 合計金額は121.0円です。
